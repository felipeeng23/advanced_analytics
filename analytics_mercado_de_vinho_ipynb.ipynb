# %% [markdown]
# <a href="https://colab.research.google.com/github/felipeeng23/advanced_analytics/blob/main/analytics_mercado_de_vinho_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
mercado_de_vinho=pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTEcKoz0mKd2kj8yyKGxIphQiPGb8vV9vujjpS3Q7hxmwcq87npoBfgHkFcyclVEU3eZgkGfMtj0O6v/pub?gid=159140889&single=true&output=csv')

# %%
mercado_de_vinho
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar chlorides  \
# 0               7.4              0.70         0.00             1.9        76
# 1               7.8              0.88         0.00             2.6        98
# 2               7.8              0.76         0.04             2.3        92
# 3              11.2              0.28         0.56             1.9        75
# 4               7.4              0.70         0.00             1.9        76
# ...             ...               ...          ...             ...       ...
# 1594            6.2              0.60         0.08             2.0      0.09
# 1595            5.9              0.55         0.10             2.2        62
# 1596            6.3              0.51         0.13             2.3        76
# 1597            5.9            645.00         0.12             2.0        75
# 1598            6.0              0.31         0.47             3.6        67
#
# ...

# %%
mercado_de_vinho.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar chlorides  \
# 0            7.4              0.70         0.00             1.9        76
# 1            7.8              0.88         0.00             2.6        98
# 2            7.8              0.76         0.04             2.3        92
# 3           11.2              0.28         0.56             1.9        75
# 4            7.4              0.70         0.00             1.9        76
#
#    free sulfur dioxide  total sulfur dioxide density    pH  sulphates alcohol  \
# 0                 11.0                  34.0   9.978  3.51       0.56     9.4
# 1                 25.0                  67.0   9.968  3.20       0.68     9.8
# 2                 15.0                  54.0     997  3.26       0.65     9.8
# 3                 17.0                  60.0     998  3.16       0.58     9.8
# 4                 11.0                  34.0   9.978  3.51       0.56     9.4
#
#    quality
# 0        5
# 1        5
# 2        5
# ...

# %%
mercado_de_vinho.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar chlorides  \
# 1594            6.2              0.60         0.08             2.0      0.09
# 1595            5.9              0.55         0.10             2.2        62
# 1596            6.3              0.51         0.13             2.3        76
# 1597            5.9            645.00         0.12             2.0        75
# 1598            6.0              0.31         0.47             3.6        67
#
#       free sulfur dioxide  total sulfur dioxide                density    pH  \
# 1594                 32.0                  44.0                  9.949  3.45
# 1595                 39.0                  51.0  9.951.200.000.000.000  3.52
# 1596                 29.0                  40.0                 99.574  3.42
# 1597                 32.0                  44.0  9.954.700.000.000.000  3.57
# 1598                 18.0                  42.0                 99.549  3.39
#
#       sulphates alcohol  quality
# ...

# %%
mercado_de_vinho.rename(columns={
    'fixed acidity':'acidez fixa',
    'volatile acidity':'acidez volátil',
    'citric acid':'ácido cítrico',
    'residual sugar':'açúcar residual',
    'chlorides':'cloro',
    'free sulfur dioxide':'dióxido de enxofre livre',
    'total sulfur dioxide':'dióxido de enxofre total',
    'density':'densidade',
    'pH':'pH',
    'sulphates':'sulfatos',
    'alcohol':'álcool',
    'quality':'qualidade',
}, inplace=True)

# %%
display(mercado_de_vinho)
# Out:
#       acidez fixa  acidez volátil  ácido cítrico  açúcar residual cloro  \
# 0             7.4            0.70           0.00              1.9    76
# 1             7.8            0.88           0.00              2.6    98
# 2             7.8            0.76           0.04              2.3    92
# 3            11.2            0.28           0.56              1.9    75
# 4             7.4            0.70           0.00              1.9    76
# ...           ...             ...            ...              ...   ...
# 1594          6.2            0.60           0.08              2.0  0.09
# 1595          5.9            0.55           0.10              2.2    62
# 1596          6.3            0.51           0.13              2.3    76
# 1597          5.9          645.00           0.12              2.0    75
# 1598          6.0            0.31           0.47              3.6    67
#
#       dióxido de enxofre livre  dióxido de enxofre total  \
# ...

# %%
# Contar o número de linhas no DataFrame
num_linhas = mercado_de_vinho.shape[0]

# Exibir o resultado
print(f"O dataset contém {num_linhas} linhas.")
# Out:
# O dataset contém 1599 linhas.

# %%
# Contar o número de colunas no DataFrame
num_colunas = mercado_de_vinho.shape[1]

# Exibir o resultado
print(f"O dataset contém {num_colunas} colunas.")
# Out:
# O dataset contém 12 colunas.

# %%
# Verificar os tipos de dados das colunas
tipos_dados = mercado_de_vinho.dtypes

# Exibir o resultado
print(tipos_dados)
# Out:
# acidez fixa                 float64
# acidez volátil              float64
# ácido cítrico               float64
# açúcar residual             float64
# cloro                        object
# dióxido de enxofre livre    float64
# dióxido de enxofre total    float64
# densidade                    object
# pH                          float64
# sulfatos                    float64
# álcool                       object
# qualidade                     int64
# dtype: object

# %%
# Contar valores nulos por coluna
dados_nulos = mercado_de_vinho.isnull().sum()

# Exibir o resultado
print(dados_nulos)
# Out:
# acidez fixa                 0
# acidez volátil              0
# ácido cítrico               0
# açúcar residual             0
# cloro                       0
# dióxido de enxofre livre    0
# dióxido de enxofre total    0
# densidade                   0
# pH                          0
# sulfatos                    0
# álcool                      0
# qualidade                   0
# dtype: int64

# %%
# Verificar se há algum valor nulo no dataset
tem_nulos = mercado_de_vinho.isnull().values.any()

print(f"Existem valores nulos no dataset? {tem_nulos}")
# Out:
# Existem valores nulos no dataset? False

# %%
# Calcular a porcentagem de valores nulos por coluna
percentual_nulos = (mercado_de_vinho.isnull().sum() / len(mercado_de_vinho)) * 100

# Exibir o resultado
print(percentual_nulos)
# Out:
# acidez fixa                 0.0
# acidez volátil              0.0
# ácido cítrico               0.0
# açúcar residual             0.0
# cloro                       0.0
# dióxido de enxofre livre    0.0
# dióxido de enxofre total    0.0
# densidade                   0.0
# pH                          0.0
# sulfatos                    0.0
# álcool                      0.0
# qualidade                   0.0
# dtype: float64

# %%
mercado_de_vinho.shape
# Out:
# (1599, 12)

# %%
mercado_de_vinho.dtypes
# Out:
# acidez fixa                 float64
# acidez volátil              float64
# ácido cítrico               float64
# açúcar residual             float64
# cloro                        object
# dióxido de enxofre livre    float64
# dióxido de enxofre total    float64
# densidade                    object
# pH                          float64
# sulfatos                    float64
# álcool                       object
# qualidade                     int64
# dtype: object

# %%
#O Non-Null count quantifica os registros nao nulos (preenchidos)
mercado_de_vinho.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   acidez fixa               1599 non-null   float64
#  1   acidez volátil            1599 non-null   float64
#  2   ácido cítrico             1599 non-null   float64
#  3   açúcar residual           1599 non-null   float64
#  4   cloro                     1599 non-null   object
#  5   dióxido de enxofre livre  1599 non-null   float64
#  6   dióxido de enxofre total  1599 non-null   float64
#  7   densidade                 1599 non-null   object
#  8   pH                        1599 non-null   float64
#  9   sulfatos                  1599 non-null   float64
#  10  álcool                    1599 non-null   object
#  11  qualidade                 1599 non-null   int64
# dtypes: float64(8), int64(1), object(3)
# memory usage: 150.0+ KB

# %%
#quantifica a quantidade de registros nulos (vazios)
mercado_de_vinho.isnull().sum()
# Out:
# acidez fixa                 0
# acidez volátil              0
# ácido cítrico               0
# açúcar residual             0
# cloro                       0
# dióxido de enxofre livre    0
# dióxido de enxofre total    0
# densidade                   0
# pH                          0
# sulfatos                    0
# álcool                      0
# qualidade                   0
# dtype: int64

# %%
mercado_de_vinho.describe()
# Out:
#        acidez fixa  acidez volátil  ácido cítrico  açúcar residual  \
# count  1599.000000     1599.000000    1599.000000      1599.000000
# mean      8.319637       81.478684       0.270976         2.538806
# std       1.741096      227.799577       0.194801         1.409928
# min       4.600000        0.120000       0.000000         0.900000
# 25%       7.100000        0.400000       0.090000         1.900000
# 50%       7.900000        0.520000       0.260000         2.200000
# 75%       9.200000        0.660000       0.420000         2.600000
# max      15.900000      975.000000       1.000000        15.500000
#
#        dióxido de enxofre livre  dióxido de enxofre total           pH  \
# count               1599.000000               1599.000000  1599.000000
# mean                  15.874922                 46.467792     3.311113
# std                   10.460157                 32.895324     0.154386
# min                    1.000000                  6.000000     2.740000
# ...

# %%
mercado_de_vinho
# Out:
#       acidez fixa  acidez volátil  ácido cítrico  açúcar residual cloro  \
# 0             7.4            0.70           0.00              1.9    76
# 1             7.8            0.88           0.00              2.6    98
# 2             7.8            0.76           0.04              2.3    92
# 3            11.2            0.28           0.56              1.9    75
# 4             7.4            0.70           0.00              1.9    76
# ...           ...             ...            ...              ...   ...
# 1594          6.2            0.60           0.08              2.0  0.09
# 1595          5.9            0.55           0.10              2.2    62
# 1596          6.3            0.51           0.13              2.3    76
# 1597          5.9          645.00           0.12              2.0    75
# 1598          6.0            0.31           0.47              3.6    67
#
#       dióxido de enxofre livre  dióxido de enxofre total  \
# ...

# %%
mercado_de_vinho.describe()
# Out:
#        acidez fixa  acidez volátil  ácido cítrico  açúcar residual  \
# count  1599.000000     1599.000000    1599.000000      1599.000000
# mean      8.319637       81.478684       0.270976         2.538806
# std       1.741096      227.799577       0.194801         1.409928
# min       4.600000        0.120000       0.000000         0.900000
# 25%       7.100000        0.400000       0.090000         1.900000
# 50%       7.900000        0.520000       0.260000         2.200000
# 75%       9.200000        0.660000       0.420000         2.600000
# max      15.900000      975.000000       1.000000        15.500000
#
#        dióxido de enxofre livre  dióxido de enxofre total           pH  \
# count               1599.000000               1599.000000  1599.000000
# mean                  15.874922                 46.467792     3.311113
# std                   10.460157                 32.895324     0.154386
# min                    1.000000                  6.000000     2.740000
# ...

# %%
sns.histplot(data=mercado_de_vinho, x='acidez fixa')
# Out:
# <Axes: xlabel='acidez fixa', ylabel='Count'>

# %%
sns.histplot(data=mercado_de_vinho, x='acidez volátil')
# Out:
# <Axes: xlabel='acidez volátil', ylabel='Count'>

# %%
sns.histplot(data=mercado_de_vinho, x='ácido cítrico')
# Out:
# <Axes: xlabel='ácido cítrico', ylabel='Count'>

# %%
sns.histplot(data=mercado_de_vinho, x='açúcar residual')
# Out:
# <Axes: xlabel='açúcar residual', ylabel='Count'>

# %%
sns.histplot(data=mercado_de_vinho, x='pH')
plt.show()

# %%
mercado_de_vinho.columns
# Out:
# Index(['acidez fixa', 'acidez volátil', 'ácido cítrico', 'açúcar residual',
#        'cloro', 'dióxido de enxofre livre', 'dióxido de enxofre total',
#        'densidade', 'pH', 'sulfatos', 'álcool', 'qualidade'],
#       dtype='object')

# %%
for col in mercado_de_vinho.columns:
    sns.histplot(data=mercado_de_vinho, x=col)
    plt.show()

# %%
#informações numéricas do gráfico de qualidade:
mercado_de_vinho["qualidade"].value_counts()
# Out:
# qualidade
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
mercado_de_vinho['qualidade'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
mercado_de_vinho["pH"]
# Out:
# 0       3.51
# 1       3.20
# 2       3.26
# 3       3.16
# 4       3.51
#         ...
# 1594    3.45
# 1595    3.52
# 1596    3.42
# 1597    3.57
# 1598    3.39
# Name: pH, Length: 1599, dtype: float64

# %%
m, s = mercado_de_vinho['pH'].mean(), mercado_de_vinho['pH'].std()
print(m)
print(s)
# Out:
# 3.3111131957473416
# 0.15438646490354266

# %%
mercado_de_vinho["pH"].apply(lambda x: (x - m) / s)
# Out:
# 0       1.288240
# 1      -0.719708
# 2      -0.331073
# 3      -0.978798
# 4       1.288240
#           ...
# 1594    0.899605
# 1595    1.353012
# 1596    0.705287
# 1597    1.676875
# 1598    0.510970
# Name: pH, Length: 1599, dtype: float64

# %%
mercado_de_vinho["pH"].apply(lambda x: (x - m) / s).apply(lambda x: abs(x)>3)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1594    False
# 1595    False
# 1596    False
# 1597    False
# 1598    False
# Name: pH, Length: 1599, dtype: bool

# %%
abs(1.288240)>3
# Out:
# False

# %%
m, s = mercado_de_vinho['pH'].mean(), mercado_de_vinho['pH'].std()
obs_eh_outlier = mercado_de_vinho["pH"].apply(lambda x: (x - m) / s).apply(lambda x: abs(x)>3)
obs_eh_outlier.value_counts()
# Out:
# pH
# False    1591
# True        8
# Name: count, dtype: int64

# %%
m, s = mercado_de_vinho['pH'].mean(), mercado_de_vinho['pH'].std()
obs_eh_outlier = mercado_de_vinho["pH"].apply(lambda x: (x - m) / s).apply(lambda x: abs(x)>3)
obs_eh_outlier.sum()
# Out:
# 8

# %%
obs_eh_outlier
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1594    False
# 1595    False
# 1596    False
# 1597    False
# 1598    False
# Name: pH, Length: 1599, dtype: bool

# %%
np.where(obs_eh_outlier)[0]
# Out:
# array([  45,   95,  151,  695, 1111, 1300, 1316, 1321])

# %%
col="pH"
m, s = mercado_de_vinho['pH'].mean(), mercado_de_vinho['pH'].std()
obs_eh_outlier = mercado_de_vinho["pH"].apply(lambda x: (x - m) / s).apply(lambda x: abs(x)>3)
outliers = np.where(obs_eh_outlier)[0]
print(f"Os outliers da coluna {col} são:\n\n{outliers}")
# Out:
# Os outliers da coluna pH são:
#
# [  45   95  151  695 1111 1300 1316 1321]

# %% [markdown]
# '='*3

# %% [markdown]
# '==='

# %%
f"\n{'='*80}\n"
# Out:
# '\n================================================================================\n'

# %%
print(f"\n{'='*80}\n")

# %%
for col in mercado_de_vinho.columns:
  m, s = mercado_de_vinho['pH'].mean(), mercado_de_vinho['pH'].std()
  obs_eh_outlier = mercado_de_vinho["pH"].apply(lambda x: (x - m) / s).apply(lambda x: abs(x)>3)
  outliers = np.where(obs_eh_outlier)[0]
  print(f"Os outliers da coluna {col} são:\n\n{outliers}")
  print(f"\n{'='*80}\n")
# Out:
# Os outliers da coluna acidez fixa são:
#
# [  45   95  151  695 1111 1300 1316 1321]
#
# ...
#
# Os outliers da coluna acidez volátil são:
#
# [  45   95  151  695 1111 1300 1316 1321]
#
# ...
#
# Os outliers da coluna ácido cítrico são:
#
# [  45   95  151  695 1111 1300 1316 1321]
#
# ...
#
# Os outliers da coluna açúcar residual são:
#
# [  45   95  151  695 1111 1300 1316 1321]
#
# ...
#
# Os outliers da coluna cloro são:
#
# [  45   95  151  695 1111 1300 1316 1321]
#
# ...
#
# Os outliers da coluna dióxido de enxofre livre são:
#
# [  45   95  151  695 1111 1300 1316 1321]
#
# ...
#
# Os outliers da coluna dióxido de enxofre total são:
#
# [  45   95  151  695 1111 1300 1316 1321]
#
# ...
#
# Os outliers da coluna densidade são:
#
# [  45   95  151  695 1111 1300 1316 1321]
#
# ...
#
# Os outliers da coluna pH são:
#
# [  45   95  151  695 1111 1300 1316 1321]
#
# ...
#
# Os outliers da coluna sulfatos são:
#
# [  45   95  151  695 1111 1300 1316 1321]
#
# ...
#
# Os outliers da coluna álcool são:
#
# ...

# %%
mercado_de_vinho["qualidade"].dtype
# Out:
# dtype('int64')

# %%
mercado_de_vinho["qualidade"].describe()
# Out:
# count    1599.000000
# mean        5.636023
# std         0.807569
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: qualidade, dtype: float64

# %%
mercado_de_vinho["qualidade"].value_counts()
# Out:
# qualidade
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
mercado_de_vinho["qualidade"].value_counts(normalize=True)
# Out:
# qualidade
# 5    0.425891
# 6    0.398999
# 7    0.124453
# 4    0.033146
# 8    0.011257
# 3    0.006254
# Name: proportion, dtype: float64

# %%
sns.histplot(data=mercado_de_vinho, x='qualidade')
# Out:
# <Axes: xlabel='qualidade', ylabel='Count'>

# %%
mercado_de_vinho["qualidade"].nunique()
# Out:
# 6

# %%
mercado_de_vinho["qualidade"]
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: qualidade, Length: 1599, dtype: int64

# %%
mercado_de_vinho["qualidade"].apply(lambda x:"bom" if x>5 else "ruim")
# Out:
# 0       ruim
# 1       ruim
# 2       ruim
# 3        bom
# 4       ruim
#         ...
# 1594    ruim
# 1595     bom
# 1596     bom
# 1597    ruim
# 1598     bom
# Name: qualidade, Length: 1599, dtype: object

# %%
mercado_de_vinho["bom_ou_ruim"] = mercado_de_vinho["qualidade"].apply(lambda x:"bom" if x>5 else "ruim")

# %%
mercado_de_vinho["bom_ou_ruim"].nunique()
# Out:
# 2

# %%
mercado_de_vinho["bom_ou_ruim"].value_counts()
# Out:
# bom_ou_ruim
# bom     855
# ruim    744
# Name: count, dtype: int64

# %%
mercado_de_vinho["bom_ou_ruim"].value_counts(normalize=True)
# Out:
# bom_ou_ruim
# bom     0.534709
# ruim    0.465291
# Name: proportion, dtype: float64

# %%
sns.histplot(data=mercado_de_vinho, x='bom_ou_ruim')
# Out:
# <Axes: xlabel='bom_ou_ruim', ylabel='Count'>

# %%
print(mercado_de_vinho.dtypes)
# Out:
# acidez fixa                 float64
# acidez volátil              float64
# ácido cítrico               float64
# açúcar residual             float64
# cloro                        object
# dióxido de enxofre livre    float64
# dióxido de enxofre total    float64
# densidade                    object
# pH                          float64
# sulfatos                    float64
# álcool                       object
# qualidade                     int64
# bom_ou_ruim                  object
# dtype: object

# %%
import pandas as pd
# Substituir os pontos que indicam milhar e converter para float
mercado_de_vinho = mercado_de_vinho.apply(lambda x: x.str.replace('.', '', regex=True) if x.dtype == "object" else x)
mercado_de_vinho = mercado_de_vinho.apply(pd.to_numeric, errors="coerce")

# %%
corr = mercado_de_vinho.drop(columns="bom_ou_ruim").corr(method="spearman")

# %%
corr["qualidade"].sort_values()
# Out:
# acidez volátil             -0.363602
# dióxido de enxofre total   -0.196735
# dióxido de enxofre livre   -0.056901
# pH                         -0.043672
# açúcar residual             0.032048
# acidez fixa                 0.114084
# ácido cítrico               0.213481
# sulfatos                    0.377060
# qualidade                   1.000000
# cloro                            NaN
# densidade                        NaN
# álcool                           NaN
# Name: qualidade, dtype: float64

# %%
print(mercado_de_vinho.dtypes)
# Out:
# acidez fixa                 float64
# acidez volátil              float64
# ácido cítrico               float64
# açúcar residual             float64
# cloro                       float64
# dióxido de enxofre livre    float64
# dióxido de enxofre total    float64
# densidade                   float64
# pH                          float64
# sulfatos                    float64
# álcool                      float64
# qualidade                     int64
# bom_ou_ruim                 float64
# dtype: object

# %%
sns.jointplot(data=mercado_de_vinho, x="pH", y="qualidade")

# %%
for col in mercado_de_vinho.drop(columns=["qualidade","bom_ou_ruim"]).columns:
  sns.jointplot(data=mercado_de_vinho, x=col, y="qualidade")
  plt.show()

# %%
mercado_de_vinho["qualidade"].sort_values().unique()
# Out:
# array([3, 4, 5, 6, 7, 8])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for corte in mercado_de_vinho["qualidade"].sort_values().unique():

    # Criando a binarização da qualidade do vinho
    binarizacao = mercado_de_vinho["qualidade"].apply(lambda x: "bom" if x > corte else "ruim")

    print(f"\nDistribuição das classes com corte = {corte}\n")
    display(binarizacao.value_counts())

    # Criando o gráfico de barras com cores personalizadas
    plt.figure(figsize=(6,4))  # Ajustando o tamanho do gráfico
    sns.countplot(x=binarizacao, palette={"bom": "royalblue", "ruim": "tomato"})  # Definição de cores específicas
    plt.title(f"Distribuição das Classes (Corte = {corte})")
    plt.xlabel("Categoria")
    plt.ylabel("Contagem")
    plt.show()
# Out:
# Distribuição das classes com corte = 3
# qualidade
# bom     1589
# ruim      10
# Name: count, dtype: int64
# <ipython-input-248-c18886539780>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=binarizacao, palette={"bom": "royalblue", "ruim": "tomato"})  # Definição de cores específicas
# Distribuição das classes com corte = 4
# qualidade
# bom     1536
# ruim      63
# Name: count, dtype: int64
# <ipython-input-248-c18886539780>:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=binarizacao, palette={"bom": "royalblue", "ruim": "tomato"})  # Definição de cores específicas
# Distribuição das classes com corte = 5
# qualidade
# bom     855
# ruim    744
# ...

# %%
corte = 5
mercado_de_vinho["bom_ou_ruim"] = mercado_de_vinho["qualidade"].apply(lambda x: "bom" if x > corte else "ruim")

# %%
mercado_de_vinho=mercado_de_vinho.drop(columns="qualidade")

# %%
mercado_de_vinho
# Out:
#       acidez fixa  acidez volátil  ácido cítrico  açúcar residual  cloro  \
# 0             7.4            0.70           0.00              1.9    NaN
# 1             7.8            0.88           0.00              2.6    NaN
# 2             7.8            0.76           0.04              2.3    NaN
# 3            11.2            0.28           0.56              1.9    NaN
# 4             7.4            0.70           0.00              1.9    NaN
# ...           ...             ...            ...              ...    ...
# 1594          6.2            0.60           0.08              2.0    NaN
# 1595          5.9            0.55           0.10              2.2    NaN
# 1596          6.3            0.51           0.13              2.3    NaN
# 1597          5.9          645.00           0.12              2.0    NaN
# 1598          6.0            0.31           0.47              3.6    NaN
#
#       dióxido de enxofre livre  dióxido de enxofre total  densidade    pH  \
# ...

# %%
mercado_de_vinho.to_csv("winequality-red_binary_target.csv")

# %%
mercado_de_vinho.describe()
# Out:
#        acidez fixa  acidez volátil  ácido cítrico  açúcar residual  cloro  \
# count  1599.000000     1599.000000    1599.000000      1599.000000    0.0
# mean      8.319637       81.478684       0.270976         2.538806    NaN
# std       1.741096      227.799577       0.194801         1.409928    NaN
# min       4.600000        0.120000       0.000000         0.900000    NaN
# 25%       7.100000        0.400000       0.090000         1.900000    NaN
# 50%       7.900000        0.520000       0.260000         2.200000    NaN
# 75%       9.200000        0.660000       0.420000         2.600000    NaN
# max      15.900000      975.000000       1.000000        15.500000    NaN
#
#        dióxido de enxofre livre  dióxido de enxofre total  densidade  \
# count               1599.000000               1599.000000        0.0
# mean                  15.874922                 46.467792        NaN
# std                   10.460157                 32.895324        NaN
# ...

# %%
mercado_de_vinho.groupby("bom_ou_ruim").describe()
# Out:
#             acidez fixa                                                 \
#                   count      mean       std  min  25%  50%   75%   max
# bom_ou_ruim
# bom               855.0  8.474035  1.862795  4.7  7.1  8.0  9.65  15.6
# ruim              744.0  8.142204  1.572396  4.6  7.1  7.8  8.90  15.9
#
#             acidez volátil              ... sulfatos       álcool           \
#                      count        mean  ...      75%   max  count mean std
# bom_ou_ruim                             ...
# bom                  855.0   54.694725  ...     0.77  1.95    0.0  NaN NaN
# ruim                 744.0  112.258636  ...     0.65  2.00    0.0  NaN NaN
#
#
#             min 25% 50% 75% max
# bom_ou_ruim
# bom         NaN NaN NaN NaN NaN
# ruim        NaN NaN NaN NaN NaN
#
# [2 rows x 88 columns]

# %%
mercado_de_vinho.groupby("bom_ou_ruim").mean()
# Out:
#              acidez fixa  acidez volátil  ácido cítrico  açúcar residual  \
# bom_ou_ruim
# bom             8.474035       54.694725       0.299883         2.535965
# ruim            8.142204      112.258636       0.237755         2.542070
#
#              cloro  dióxido de enxofre livre  dióxido de enxofre total  \
# bom_ou_ruim
# bom            NaN                 15.272515                 39.352047
# ruim           NaN                 16.567204                 54.645161
#
#              densidade        pH  sulfatos  álcool
# bom_ou_ruim
# bom                NaN  3.310643  0.692620     NaN
# ruim               NaN  3.311653  0.618535     NaN

# %%
print(mercado_de_vinho.columns)
# Out:
# Index(['acidez fixa', 'acidez volátil', 'ácido cítrico', 'açúcar residual',
#        'cloro', 'dióxido de enxofre livre', 'dióxido de enxofre total',
#        'densidade', 'pH', 'sulfatos', 'álcool', 'bom_ou_ruim'],
#       dtype='object')

# %%
mercado_de_vinho["bom_ou_ruim"] = mercado_de_vinho["bom_ou_ruim"].astype(str)

# %%
mercado_de_vinho.columns [:-1]
# Out:
# Index(['acidez fixa', 'acidez volátil', 'ácido cítrico', 'açúcar residual',
#        'cloro', 'dióxido de enxofre livre', 'dióxido de enxofre total',
#        'densidade', 'pH', 'sulfatos', 'álcool'],
#       dtype='object')

# %%
sns.pairplot(mercado_de_vinho, hue="bom_ou_ruim")

# %%
mercado_de_vinho.groupby("bom_ou_ruim").mean()
# Out:
#              acidez fixa  acidez volátil  ácido cítrico  açúcar residual  \
# bom_ou_ruim
# bom             8.474035       54.694725       0.299883         2.535965
# ruim            8.142204      112.258636       0.237755         2.542070
#
#              cloro  dióxido de enxofre livre  dióxido de enxofre total  \
# bom_ou_ruim
# bom            NaN                 15.272515                 39.352047
# ruim           NaN                 16.567204                 54.645161
#
#              densidade        pH  sulfatos  álcool
# bom_ou_ruim
# bom                NaN  3.310643  0.692620     NaN
# ruim               NaN  3.311653  0.618535     NaN

# %%
mercado_de_vinho.groupby("bom_ou_ruim").var()
# Out:
#              acidez fixa  acidez volátil  ácido cítrico  açúcar residual  \
# bom_ou_ruim
# bom             3.470004    34382.920525       0.039955         2.030154
# ruim            2.472429    70313.871457       0.033624         1.941983
#
#              cloro  dióxido de enxofre livre  dióxido de enxofre total  \
# bom_ou_ruim
# bom            NaN                100.772253                742.741258
# ruim           NaN                118.598438               1348.392763
#
#              densidade        pH  sulfatos  álcool
# bom_ou_ruim
# bom                NaN  0.023887  0.024198     NaN
# ruim               NaN  0.023807  0.031044     NaN

# %%
pop_vinhos_bons = mercado_de_vinho.query("bom_ou_ruim == 'bom'")
pop_vinhos_ruins = mercado_de_vinho.query("bom_ou_ruim == 'ruim'")

# %%
import scipy

col = "pH"

t, p = scipy.stats.ttest_ind(
    pop_vinhos_bons[col],
    pop_vinhos_ruins[col],
    alternative='two-sided',
    equal_var=False,
)

sig = 0.05

print(f"\nPara a coluna {col} (t={t:.2f}, p={p:.2f}), a um nível de signficância {sig}, temos a conclusão:\n")

if p > sig:
    print("Falha em rejeitar H0: não existe evidência para dizer que as médias são diferentes! Ou seja, não parece haver separabilidade com relação às médias!")
else:
    print("Rejeitamos H0: há evidência de que as médias são diferentes! Ou seja, há indício de separabilidade com relação às médias!")

print(f"\n{'='*80}\n")
# Out:
# Para a coluna pH (t=-0.13, p=0.90), a um nível de signficância 0.05, temos a conclusão:
#
# Falha em rejeitar H0: não existe evidência para dizer que as médias são diferentes! Ou seja, não parece haver separabilidade com relação às médias!
#
# ...

# %%
for col in mercado_de_vinho.columns[:-1]:

    t, p = scipy.stats.ttest_ind(
        pop_vinhos_bons[col],
        pop_vinhos_ruins[col],
        alternative='two-sided',
        equal_var=False,
    )

    sig = 0.05

    print(f"\nPara a coluna {col} (t={t:.2f}, p={p:.5f}), a um nível de signficância {sig}, temos a conclusão:\n")

    if p > sig:
        print("Falha em rejeitar H0: não existe evidência para dizer que as médias são diferentes! Ou seja, não parece haver separabilidade com relação às médias!")
    else:
        print("Rejeitamos H0: há evidência de que as médias são diferentes! Ou seja, há indício de separabilidade com relação às médias!")

    print(f"\n{'='*80}\n")
# Out:
# Para a coluna acidez fixa (t=3.86, p=0.00012), a um nível de signficância 0.05, temos a conclusão:
#
# Rejeitamos H0: há evidência de que as médias são diferentes! Ou seja, há indício de separabilidade com relação às médias!
#
# ...
#
#
# Para a coluna acidez volátil (t=-4.96, p=0.00000), a um nível de signficância 0.05, temos a conclusão:
#
# Rejeitamos H0: há evidência de que as médias são diferentes! Ou seja, há indício de separabilidade com relação às médias!
#
# ...
#
#
# Para a coluna ácido cítrico (t=6.48, p=0.00000), a um nível de signficância 0.05, temos a conclusão:
#
# Rejeitamos H0: há evidência de que as médias são diferentes! Ou seja, há indício de separabilidade com relação às médias!
#
# ...
#
#
# Para a coluna açúcar residual (t=-0.09, p=0.93110), a um nível de signficância 0.05, temos a conclusão:
#
# Falha em rejeitar H0: não existe evidência para dizer que as médias são diferentes! Ou seja, não parece haver separabilidade com relação às médias!
#
# ...
#
#
# ...

# %% [markdown]
# Conclusão: temos um problema de classificação cujas classes não são trivialmente separadas!
#
# No entanto, existe sim alguma separabilidade: então há esperança de que conseguiremos construir algum modelo minimamente performático!
#
# Em reunião com negócio, alinhamos dois pontos:
#
# 1°: expectativas quanto à performance do modelo, dada a dificuldade do problema;
#
# 2°: deixamos aberta a porta e criamos a "curiosidade" por parte do negócio de saber sobre a performance do modelo.
#
# Expectativas alinhadas!
